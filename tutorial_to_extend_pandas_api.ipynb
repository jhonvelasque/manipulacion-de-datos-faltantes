# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd

# %% [markdown]
# ## Datos de prueba

# %%
df = pd.DataFrame.from_dict(
    data = {
        "a": list("asdfasdfas"),
        "b": range(0, 10)
    }
)

df.iloc[2:5, 0] = None
df.iloc[6:7, 1] = None

df
# Out:
#       a    b
# 0     a  0.0
# 1     s  1.0
# 2  None  2.0
# 3  None  3.0
# 4  None  4.0
# 5     s  5.0
# 6     d  NaN
# 7     f  7.0
# 8     a  8.0
# 9     s  9.0

# %%
df.a.str

# %%
# df.missing

# %% [markdown]
# ## Crear una nueva clase para extender pandas

# %%
try:
    del pd.DataFrame.missing
except AttributeError:
    pass

@pd.api.extensions.register_dataframe_accessor("missing")
class DontMissMe:
    def __init__(self, pandas_obj):
        self._obj = pandas_obj

    def number_missing(self):
        return self._obj.isna().sum().sum()

    def number_complete(self):
        return self._obj.size - self._obj.missing.number_missing()

    def proportion_missing(self):
        pass

# %% [markdown]
# ## Probar uso

# %%
df = pd.DataFrame(df)

# %%
df.missing.number_missing()
# Out:
# 4

# %%
df.missing.number_complete()
# Out:
# 16

# %%
df.missing.proportion_missing()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f8472c9f-32c3-41c5-97ae-30897975bce5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

# %%
try:
    del pd.DataFrame.jhon
except AttributeError:
    pass
#decorador que altera pandas crea un aceso directo 
@pd.api.extensions.register_dataframe_accessor("jhon")
class metodos:
    # constructor 
    def __init__(self, pandas_obj):
        #es una variable privada 
        self._obj = pandas_obj

    def number_missing(self):
        return self._obj.isna().sum().sum()

    def number_complete(self):
        return self._obj.size - self._obj.missing.number_missing()

    def proportion_missing(self):
        pass

# %%
df.jhon.number_missing()
# Out:
# 4

# %%
class coordenada :
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def distancia(self):
        x_diff=self.x-3
        return x_diff
if __name__=='__main__':
    cord1=coordenada(15,5)

    print(cord1.distancia())
# Out:
# 12

# %%
#Clases
class Persona:

    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

    def saluda(self, otra_persona):
        return f'Hola {otra_persona.nombre}, me llamo {self.nombre}.'

# uso
david = Persona('David', 35)
erika = Persona('Erika', 32)
print(david.saluda(erika))
# Out:
# Hola Erika, me llamo David.
